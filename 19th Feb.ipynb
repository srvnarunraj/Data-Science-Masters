# %% [markdown]
# # 1.	What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# * Flask is a popular Python web framework that allows developers to build web applications quickly and efficiently.
# * It is a lightweight framework that doesn't have any particular project layout or required libraries, making it flexible and easy to use
# * **Advantages :**
# 	* **Simplicity:** Flask is a lightweight and minimalistic web framework that is easy to learn and use
#
# 	* **Flexibility:** Flask can be able to customize  web applications to our  exact needs. It is also compatible with a wide range of third-party libraries and extensions.
#
# 	* **Large Community:** Flask has a large and active community of developers who are always ready to help and provide support.
#
# 	* **Fast Development:** Flask helps to build web applications quickly and efficiently,
#
# 	* **Scalability:** Flask is a scalable framework that can be used to build applications of any size.

# %% [markdown]
# # 2.	Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.

# %%
from flask import Flask
app = Flask(__name__)

@app.route("/")
def hw():
    return "<h1>Hello World</h1>"

if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![image.png](attachment:1481e9d1-51c9-4a81-9963-82c05d628837.png)

# %% [markdown]
# # 3.	What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# * App routing in flask is used to map the python functions to the url

# %%
from flask import Flask

app = Flask(__name__)

@app.route('/')
def home():
    return 'Hello, World!'

# %% [markdown]
# # 4.	Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/” route to show the following details:

# %%
from flask import Flask
app = Flask(__name__)

@app.route("/welcome")
def Welcome():
    return "<h1>Welcome to ABC Corporation</h1>"

@app.route("/")
def details():
    c_details = "Company Name: ABC Corporation <br> Location: India <br>  Contact Detail: 999-999-9999"
    return c_details

if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# # ![image.png](attachment:fcd56533-39b3-420a-8896-94ceb132958b.png)

# %% [markdown]
# # ![image.png](attachment:8307e4c3-4644-4fc5-8298-d52899719f5e.png)

# %% [markdown]
# # 5.	What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.

# %% [markdown]
#  * url_for() function is used in Flask for URL Building

# %%
@app.route("/usignup")
def signup():
    name = request.args.get('uname')
    return "<h1>Hello {}</h1>".format(name)

@app.route("/login/<user>")
def profile(user):
    return "<h1>Hello {}</h1>".format(user)

with app.test_request_context():
    print(url_for('signup',uname='ArunRaj'))
    print(url_for('profile', user='MrRaj'))

# %% [markdown]
# #### /usignup?uname=ArunRaj
# #### /login/MrRaj
