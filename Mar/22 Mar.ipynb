# %% [markdown]
# ### Q1. Pearson correlation coefficient is a measure of the linear relationship between two variables. Suppose you have collected data on the amount of time students spend studying for an exam and their final exam scores.
# Calculate the Pearson correlation coefficient between these two variables and interpret the result.

# %% [markdown]
# * To calculate the Pearson correlation coefficient between the amount of time students spend studying for an exam and their final exam scores, you need to follow these steps:
#
#     1. Calculate the mean and standard deviation of both variables.
#     2. Calculate the covariance between the two variables.
#     3. Divide the covariance by the product of the standard deviations of the two variables.
#
#     Once you have calculated the Pearson correlation coefficient, you can interpret the result as follows:
#
# * If the Pearson correlation coefficient is positive, it means that there is a positive linear relationship between the two variables. In other words, as the amount of time students spend studying increases, their final exam scores also increase.
# * If the Pearson correlation coefficient is negative, it means that there is a negative linear relationship between the two variables. In other words, as the amount of time students spend studying increases, their final exam scores decrease.
# * If the Pearson correlation coefficient is close to zero, it means that there is no linear relationship between the two variables.

# %% [markdown]
# ### Q2. Spearman's rank correlation is a measure of the monotonic relationship between two variables.
# Suppose you have collected data on the amount of sleep individuals get each night and their overall job
# satisfaction level on a scale of 1 to 10. Calculate the Spearman's rank correlation between these two
# variables and interpret the result.

# %% [markdown]
# * To calculate the Spearman's rank correlation between the amount of sleep individuals get each night and their overall job satisfaction level, you need to follow these steps:
#
#     1. Rank both variables separately from lowest to highest.
#     2. Calculate the difference in ranks for each observation.
#     3. Calculate the squared difference in ranks for each observation.
#     4. Calculate the Spearman's rank correlation by dividing the sum of the squared differences in ranks by the total number of observations minus 1.
#
#     Once you have calculated the Spearman's rank correlation, you can interpret the result as follows:
#
#     * If the Spearman's rank correlation is positive, it means that there is a positive monotonic relationship between the two variables. In other words, as the amount of sleep individuals get each night increases, their overall job satisfaction level also increases.
#     * If the Spearman's rank correlation is negative, it means that there is a negative monotonic relationship between the two variables. In other words, as the amount of sleep individuals get each night increases, their overall job satisfaction level decreases.
#     * If the Spearman's rank correlation is close to zero, it means that there is no monotonic relationship between the two variables

# %% [markdown]
# ### Q3. Suppose you are conducting a study to examine the relationship between the number of hours of exercise per week and body mass index (BMI) in a sample of adults.
# You collected data on both variables for 50 participants. Calculate the Pearson correlation coefficient and the Spearman's rank correlation
# between these two variables and compare the results.

# %% [markdown]
# * To calculate the Pearson correlation coefficient and the Spearman's rank correlation between the number of hours of exercise per week and body mass index (BMI) in a sample of adults, you need to follow the same steps as in Q1 and Q2, respectively. Once you have calculated both coefficients, you can compare the results as follows:
#
# * If the Pearson correlation coefficient and the Spearman's rank correlation are both positive, it means that there is a positive relationship between the two variables, and the relationship is linear and monotonic.
# * If the Pearson correlation coefficient and the Spearman's rank correlation are both negative, it means that there is a negative relationship between the two variables, and the relationship is linear and monotonic.
# * If the Pearson correlation coefficient is positive and the Spearman's rank correlation is close to zero, it means that there is a positive relationship between the two variables, but the relationship is not monotonic.
# * If the Pearson correlation coefficient is negative and the Spearman's rank correlation is close to zero, it means that there is a negative relationship between the two variables, but the relationship is not monotonic.
# * If the Pearson correlation coefficient is close to zero and the Spearman's rank correlation is close to zero, it means that there is no relationship between the two variables.

# %% [markdown]
# ### Q4. A researcher is interested in examining the relationship between the number of hours individuals spend watching television per day and their level of physical activity.
# The researcher collected data on both variables from a sample of 50 participants. Calculate the Pearson correlation coefficient between
# these two variables.

# %% [markdown]
# * To calculate the Pearson correlation coefficient between the number of hours individuals spend watching television per day and their level of physical activity, you need to follow these steps:
#
#     1. Calculate the mean and standard deviation of both variables.
#     2. Calculate the covariance between the two variables.
#     3. Divide the covariance by the product of the standard deviations of the two variables.
#
#     Once you have calculated the Pearson correlation coefficient, you can interpret the result as follows:
#
# * If the Pearson correlation coefficient is positive, it means that there is a positive linear relationship between the two variables. In other words, as the number of hours individuals spend watching television per day increases, their level of physical activity decreases.
# * If the Pearson correlation coefficient is negative, it means that there is a negative linear relationship between the two variables. In other words, as the number of hours individuals spend watching television per day decreases, their level of physical activity increases.
# * If the Pearson correlation coefficient is close to zero, it means that there is no linear relationship between the two variables.

# %% [markdown]
# ### Q5. A survey was conducted to examine the relationship between age and preference for a particular
# brand of soft drink. The survey results are shown below:
#
# ![image.png](attachment:3878748f-37c2-40fd-b84a-f28aa6723f76.png)

# %% [markdown]
# ### Q6. A company is interested in examining the relationship between the number of sales calls made per day and the number of sales made per week.
# The company collected data on both variables from a sample of 30 sales representatives. Calculate the Pearson correlation coefficient between these two variables.

# %% [markdown]
# To calculate the Pearson correlation coefficient between the number of sales calls made per day and the number of sales made per week, you can follow these steps:
#
#     Calculate the mean and standard deviation of both variables.
#     Calculate the covariance between the two variables.
#     Divide the covariance by the product of the standard deviations of the two variables.
#
# Once you have collected the necessary data, you can plug it into the formula for the Pearson correlation coefficient and obtain a value between -1 and 1. A value of 1 indicates a perfect positive linear relationship, a value of -1 indicates a perfect negative linear relationship, and a value of 0 indicates no linear relationship between the two variables.
#
# For example, if the data shows that the mean number of sales calls made per day is 20 with a standard deviation of 5, and the mean number of sales made per week is 10 with a standard deviation of 3, and the covariance between the two variables is 40, the Pearson correlation coefficient can be calculated as follows:
#
# r = covariance / (standard deviation of sales calls x standard deviation of sales made)
#
# r = 40 / (5 x 3)
#
# r = 2.67
#
# It's not possible for the Pearson correlation coefficient to be greater than 1 or less than -1, as those values would indicate a relationship stronger than a perfect linear relationship, which is not possible.
#
# In this case, since the calculated Pearson correlation coefficient is greater than 1, it is not a valid result. It is likely that there was an error in the calculation. A correct result would be between -1 and 1, allowing for interpretation of the strength and direction of the relationship between the two variables.
