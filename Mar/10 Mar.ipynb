# %% [markdown]
# ### Q1: What is Estimation Statistics? Explain point estimate and interval estimate.

# %% [markdown]
# **Estimation statistics:** involves using sample data to make inferences about a population parameter. There are two types of estimation: point estimate and interval estimate.
# 1. **point estimate :** is a single value used to estimate a population parameter. It is usually calculated as a sample statistic, such as the sample mean or sample proportion.
#
# 2. **An interval estimate  :** a range of values that is likely to contain the population parameter. It is calculated using a sample statistic and a margin of error. A confidence interval is an example of an interval estimate.

# %% [markdown]
# ### Q2. Write a Python function to estimate the population mean using a sample mean and standard deviation.

# %%
import math

def popmean(sample_mean, sample_std_dev, sample_size):
    standard_error = sample_std_dev / math.sqrt(sample_size)
    z_critical_value = 1.96 
    margin_of_error = z_critical_value * standard_error
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error
    return (lower_bound, upper_bound)

# %% [markdown]
# ### Q3: What is Hypothesis testing? Why is it used? State the importance of Hypothesis testing.

# %% [markdown]
# Hypothesis testing is a statistical method used to determine whether a hypothesis about a population parameter is supported by the sample data. It involves comparing the sample data to the null hypothesis, which is the hypothesis that there is no significant difference between the sample data and the population parameter.
#
# Hypothesis testing is used to make decisions based on the sample data, such as whether to reject or fail to reject the null hypothesis. It is important because it allows us to make inferences about a population parameter based on a sample of data, which can be used to inform decisions or make predictions.

# %% [markdown]
# ### Q4. Create a hypothesis that states whether the average weight of male college students is greater than the average weight of female college students.

# %% [markdown]
# **Null Hypothesis:** The average weight of male college students is equal to or less than the average weight of female college students.
#
# **Alternative Hypothesis:** The average weight of male college students is greater than the average weight of female college students.

# %% [markdown]
# ### Q5. Write a Python script to conduct a hypothesis test on the difference between two population means, given a sample from each population.

# %%
import numpy as np
from scipy.stats import ttest_ind

pop1 = np.array([1, 2, 3, 4, 5])
pop2 = np.array([6, 7, 8, 9, 10])

x1 = pop1.mean()
s1 = pop1.std(ddof=1)
n1 = len(pop1)

x2 = pop2.mean()
s2 = pop2.std(ddof=1)
n2 = len(pop2)

t = (x1 - x2) / np.sqrt(s12/n1 + s22/n2)

df = n1 + n2 - 2

cv = ttest_ind(pop1, pop2, equal_var=False)[2]

p = ttest_ind(pop1, pop2, equal_var=False)[1]

print("Test statistic: {:.2f}".format(t))
print("Degrees of freedom: {}".format(df))
print("Critical value of t: {:.2f}".format(cv))
print("p-value: {:.4f}".format(p))

if t < -cv or t > cv:
	print("Reject the null hypothesis")
else:
	print("Fail to reject the null hypothesis")

# %% [markdown]
# ### Q6: What is a null and alternative hypothesis? Give some examples.

# %% [markdown]
# **null hypothesis :**  statement that assumes there is no significant difference or relationship between two variables in a population. It is usually denoted as H0.
#
# **alternative hypothesis :** statement that assumes there is a significant difference or relationship between two variables in a population. It is usually denoted as Ha.
#
# Examples of null and alternative hypotheses are:
# 1. Null hypothesis: There is no difference in the average height of male and female students in a college population. Alternative hypothesis: The average height of male students is significantly different from the average height of female students in a college population.
# 2. Null hypothesis: There is no relationship between smoking and lung cancer. Alternative hypothesis: There is a significant relationship between smoking and lung cancer

# %% [markdown]
# ### Q7: Write down the steps involved in hypothesis testing.

# %% [markdown]
# The steps involved in hypothesis testing are:
#
# 1. State the null and alternative hypotheses
# 2. Determine the level of significance (alpha)
# 3. Determine the test statistic and the corresponding distribution
# 4. Collect the data and calculate the test statistic
# 5. Calculate the p-value
# 6. Make a decision and interpret the results
# 7. Draw conclusions and make recommendations

# %% [markdown]
# ### Q8. Define p-value and explain its significance in hypothesis testing.

# %% [markdown]
# * p-value is the probability of obtaining a test statistic at least as extreme as the one observed, assuming that the null hypothesis is true.
# * It measures the strength of evidence against the null hypothesis. If the p-value is less than the level of significance (alpha), then we reject the null hypothesis and conclude that there is evidence for the alternative hypothesis. If the p-value is greater than or equal to alpha, then we fail to reject the null hypothesis.

# %% [markdown]
# ### Q9. Generate a Student's t-distribution plot using Python's matplotlib library, with the degrees of freedom parameter set to 10.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import t

df = 10
x = np.linspace(t.ppf(0.001, df), t.ppf(0.999, df), 100)
plt.plot(x, t.pdf(x, df))
plt.title("Student's t-Distribution (df=10)")
plt.xlabel('x')
plt.ylabel('PDF')
plt.show()

# %% [markdown]
# ### Q10. Write a Python program to calculate the two-sample t-test for independent samples, given two random samples of equal size and a null hypothesis that the population means are equal.

# %%
import numpy as np
from scipy.stats import ttest_ind

# Generate two random samples of equal size
sample1 = np.random.normal(10, 2, 100)
sample2 = np.random.normal(12, 2, 100)

# Calculate the t-test
t, p = ttest_ind(sample1, sample2)

# Print the results
print("t = ", t)
print("p = ", p)
# Out:
# t =  -7.926409625864561
# p =  1.608260428364215e-13

# %% [markdown]
# ### Q11: What is Student’s t distribution? When to use the t-Distribution.

# %% [markdown]
# The Student's t-distribution is a probability distribution that arises when the sample size is small and the population standard deviation is unknown. It is a family of distributions that depend on the degrees of freedom, which is equal to the sample size minus one. The t-distribution is similar in shape to the standard normal distribution, but it has heavier tails, which means that it assigns more probability to extreme values.
#
# The t-distribution is used in hypothesis testing when the sample size is small and the population standard deviation is unknown. It is also used to construct confidence intervals for the population mean when the sample size is small and the population standard deviation is unknown.

# %% [markdown]
# ### Q12: What is t-statistic? State the formula for t-statistic.

# %% [markdown]
# The t-statistic is a measure of how far the sample mean deviates from the hypothesized population mean, in units of the standard error of the mean. It is used in hypothesis testing to determine whether there is evidence to reject the null hypothesis.
#
# The formula for the t-statistic is:
#
# t = (x - μ) / (s / sqrt(n))
#
# where x is the sample mean, μ is the hypothesized population mean, s is the sample standard deviation, and n is the sample size.

# %% [markdown]
# ### Q13. A coffee shop owner wants to estimate the average daily revenue for their shop. They take a random sample of 50 days and find the sample mean revenue to be $500 with a standard deviation of $50. Estimate the population mean revenue with a 95% confidence interval.

# %% [markdown]
# <pre>
# Given,
# 	sample size n = 50,
#     sample mean x̄ = $500 and
#     sample standard deviation s = $50.
#
# The formula for the confidence interval for population mean is:
#
# Confidence interval = x̄ ± z* (s/√n)
#
# where x̄ is the sample mean, s is the sample standard deviation, n is the sample size, and z* is the critical value of the standard normal distribution for the given level of confidence.
#
# At 95% confidence level, α = 0.05/2 = 0.025 (since it's a two-tailed test). The corresponding z-value can be obtained from the standard normal distribution table or using a calculator.
#
# Using the table, we can find that the z-value for 0.025 is 1.96.
#
# Therefore, the 95% confidence interval is:
#
# $500 ± 1.96 * ($50 / √50) = $500 ± $14.14
# </pre>
# Hence, the 95% confidence interval for the population mean revenue is ($485.86, $514.14). We can be 95% confident that the true population mean revenue lies within this interval.

# %% [markdown]
# ### Q14. A researcher hypothesizes that a new drug will decrease blood pressure by 10 mmHg. They conduct a clinical trial with 100 patients and find that the sample mean decrease in blood pressure is 8 mmHg with a standard deviation of 3 mmHg. Test the hypothesis with a significance level of 0.05.

# %% [markdown]
# The null hypothesis is that the new drug will not decrease blood pressure by 10 mmHg:
# H0: μ = 10
#
# The alternative hypothesis is that the new drug will decrease blood pressure by 10 mmHg:
# Ha: μ < 10
#
# The significance level is 0.05.
#
# The test statistic for this hypothesis test is a t-statistic, which can be calculated as follows:
#
# t = (x̄ - μ) / (s / √n)
#
# where x̄ is the sample mean, μ is the hypothesized population mean, s is the sample standard deviation, and n is the sample size.
#
# Plugging in the values, we get:
#
# t = (8 - 10) / (3 / √100) = -2.82
#
# Using a t-distribution table with degrees of freedom (df) = n - 1 = 99, the critical value for a one-tailed test at the 0.05 significance level is -1.66. Since our test statistic (-2.82) is less than the critical value, we can reject the null hypothesis and conclude that there is sufficient evidence to suggest that the new drug decreases blood pressure by 10 mmHg.

# %% [markdown]
# ### Q15. An electronics company produces a certain type of product with a mean weight of 5 pounds and a standard deviation of 0.5 pounds. A random sample of 25 products is taken, and the sample mean weight is found to be 4.8 pounds. Test the hypothesis that the true mean weight of the products is less than 5 pounds with a significance level of 0.01.

# %% [markdown]
# The null hypothesis is that the true mean weight of the products is equal to 5 pounds:
# H0: μ = 5
#
# The alternative hypothesis is that the true mean weight of the products is less than 5 pounds:
# Ha: μ < 5
#
# The significance level is 0.01.
#
# The test statistic for this hypothesis test is a t-statistic, which can be calculated as follows:
#
# t = (x̄ - μ) / (s / √n)
#
# where x̄ is the sample mean, μ is the hypothesized population mean, s is the sample standard deviation, and n is the sample size.
#
# Plugging in the values, we get:
#
# t = (4.8 - 5) / (0.5 / √25) = -2
#
# Using a t-distribution table with degrees of freedom (df) = n - 1 = 24, the critical value for a one-tailed test at the 0.01 significance level is -2.492. Since our test statistic (-2) is greater than the critical value, we fail to reject the null hypothesis and conclude that there is insufficient evidence to suggest that the true mean weight of the products is less than 5 pounds.

# %% [markdown]
# ### Q16. Two groups of students are given different study materials to prepare for a test.
# The first group (n1 =30) has a mean score of 80 with a standard deviation of 10, and the second group (n2 = 40) has a mean
# score of 75 with a standard deviation of 8. Test the hypothesis that the population means for the two
# groups are equal with a significance level of 0.01.

# %% [markdown]
# The null hypothesis is that the population means are equal, and the alternative hypothesis is that they are not equal. We can use a significance level of 0.01, which means that we are willing to reject the null hypothesis if the probability of obtaining the observed difference in means by chance is less than 0.01.
#
# To perform the test, we can first calculate the test statistic:
#
# t = (x1 - x2) / sqrt(s1^2/n1 + s2^2/n2)
#
# where x1 and x2 are the sample means, s1 and s2 are the sample standard deviations, and n1 and n2 are the sample sizes.
#
# Substituting the given values, we get:
#
# t = (80 - 75) / sqrt((10^2/30) + (8^2/40)) = 2.60
#
# The degrees of freedom for the test are calculated as:
#
# df = (s1^2/n1 + s2^2/n2)^2 / ((s1^2/n1)^2/(n1-1) + (s2^2/n2)^2/(n2-1))
#
# Substituting the given values, we get:
#
# df = ((10^2/30) + (8^2/40))^2 / (((10^2/30)^2/29) + ((8^2/40)^2/39)) = 64.4
#
# Using a t-distribution table or calculator with 64.4 degrees of freedom and a significance level of 0.01, we find the critical value to be ±2.66.
#
# Since our calculated t-value of 2.60 is within the range of the critical values, we fail to reject the null hypothesis. Therefore, we do not have sufficient evidence to conclude that the population means for the two groups are different at the 0.01 significance leve

# %% [markdown]
# ### Q17. A marketing company wants to estimate the average number of ads watched by viewers during a TV program.
# They take a random sample of 50 viewers and find that the sample mean is 4 with a standard deviation of 1.5. Estimate the population mean with a 99% confidence interval.

# %% [markdown]
# CI = x̄ ± z*(s/√n)
#
# where x̄ is the sample mean, s is the sample standard deviation, n is the sample size, and z is the critical value from the standard normal distribution corresponding to a 99% confidence level (z = 2.576).
#
# Substituting the given values, we get:
#
# CI = 4 ± 2.576*(1.5/√50) = (3.63, 4.37)
#
# Therefore, we can be 99% confident that the population mean number of ads watched by viewers during a TV program falls within the interval of 3.63 to 4.37.
